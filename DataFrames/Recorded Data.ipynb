# %% [markdown]
# # Mini Project:
# Recorded nrecords by user input

# %%
import pandas as pd
import csv
print("------------------------ USing Data Frame -------------")
print("Records PIAIC of PIAIC Students")
print('============================')
records=["Name","Course","Timing","Contact No","Email","Campus","Quarter"]  #its shows the message if i use dic as record..
                                                                            #then i can not show the messgae what is record by
                                                                            #user
                                                                            #and then it will be difficult to maintain index of dic
                                                                            #to pick up the data from dic
Recorded_record_names=[]
Recorded_record_Course=[]
Recorded_record_Timing=[]
Recorded_record_Email=[]
Recorded_record_Contact=[]
Recorded_record_Campus=[]
Recorded_record_Quarter=[]
for i in records:
    print("-",i)


user_input1=input("Want to Enter your record : ").title()
if user_input1=="Yes":
    Name=input("Enter your name please : ")
    Course=input("Enter Your Course : ")
    Timing=input("Enter Your Timinng : ")
    Email=input("Enter your Email : ")
    Contact_no=input("Enter Your Contact No : ")
    Campus=input("Enter Your Campus : ")
    Quarter=input("Enter Your Quarter : ")
    Recorded_record_names.append(Name)
    Recorded_record_Course.append(Course)
    Recorded_record_Timing.append(Timing)
    Recorded_record_Email.append(Email)
    Recorded_record_Contact.append(Contact_no)
    Recorded_record_Campus.append(Campus)
    Recorded_record_Quarter.append(Quarter)
    data={ "Name" :  Recorded_record_names , "Course" : Recorded_record_Course , "Timings":Recorded_record_Timing,
           "Email" : Recorded_record_Email ,  "Contact No" : Recorded_record_Contact , "Campus" :Recorded_record_Campus,
           "Quarter" : Recorded_record_Quarter
        
    }
    
    
    user_input2=input("Want to Enter your  friends Record : ").title()
    if user_input2=="Yes":
        user_input3=int(input("How many friend's record u want to be recorded ! Input in values please : "))
        print()
        for i in range(user_input3):
             Name=input("Enter your name please : ")
             Course=input("Enter Your Course : ")
             Timing=input("Enter Your Timinng : ")
             Email=input("Enter your Email : ")
             Contact_no=input("Enter Your Contact No : ")
             Campus=input("Enter Your Campus : ")
             Quarter=input("Enter Your Quarter : ")
             Recorded_record_names.append(Name)
             Recorded_record_Course.append(Course)
             Recorded_record_Timing.append(Timing)
             Recorded_record_Email.append(Email)
             Recorded_record_Contact.append(Contact_no)
             Recorded_record_Campus.append(Campus)
             Recorded_record_Quarter.append(Quarter)
             data={ "Name  " :  Recorded_record_names , "Course" : Recorded_record_Course , "Timings":Recorded_record_Timing,
                    "Email" : Recorded_record_Email ,  "Contact No" : Recorded_record_Contact , "Campus" :Recorded_record_Campus,
                    "Quarter" : Recorded_record_Quarter
                  }
            
        
    else:
        print("Thanks You !")
else:
    print("Thanks You !")
        

print("\n")
Std_data=pd.DataFrame(data)
print("==============================================================================================================")
print("\t\t\t\t\t Recorded Table")
print("==============================================================================================================")
print(Std_data)
# Out:
# ------------------------ USing Data Frame -------------
# Records PIAIC of PIAIC Students
# ...
# - Name
# - Course
# - Timing
# - Contact No
# - Email
# - Campus
# - Quarter
# Want to Enter your record : yes
# Enter your name please : Sadiq shah
# Enter Your Course : AI
# Enter Your Timinng : 9 to 1
# Enter your Email : shahsadiq208
# Enter Your Contact No : 34322
# Enter Your Campus : SBSA
# Enter Your Quarter : 2nd
# Want to Enter your  friends Record : no
# Thanks You !
#
#
# ...
# 					 Recorded Table
# ...
#          Name Course Timings         Email Contact No Campus Quarter
# 0  Sadiq shah     AI  9 to 1  shahsadiq208      34322   SBSA     2nd

# %%
import pandas as pd
import datetime
import math
import requests
import sqlite3

# %%
import numpy as np

# %%
test_1= pd.read_csv('test21.txt',delimiter = ' ' , parse_dates = True)

# %%
test_1
# Out:
#    emp_id emp_name  emp_age dept.     joining
# 0       1     inam     42.0   A.I  2018-04-01
# 1       2   fayyaz     25.0   NaN  2018-04-02
# 2       3     asad     16.0   NaN         NaN
# 3       4     aqsa      NaN   NaN         NaN

# %%
test_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
# emp_id      4 non-null int64
# emp_name    4 non-null object
# emp_age     3 non-null float64
# dept.       1 non-null object
# joining     2 non-null object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 240.0+ bytes

# %%
x=pd.read_clipboard()

# %%
x
# Out:
#                         Company           Contact  Country
# 0           Alfreds Futterkiste      Maria Anders  Germany
# 1    Centro comercial Moctezuma   Francisco Chang   Mexico
# 2                  Ernst Handel     Roland Mendel  Austria
# 3                Island Trading     Helen Bennett       UK
# 4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
# 5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy

# %%
y=pd.read_excel('excel1.xlsx')

# %%
y
# Out:
#                         Company           Contact  Country
# 0           Alfreds Futterkiste      Maria Anders   france
# 1    Centro comercial Moctezuma   Francisco Chang   Mexico
# 2                  Ernst Handel     Roland Mendel  Austria
# 3                Island Trading     Helen Bennett       UK
# 4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
# 5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy

# %%
z = pd.read_html('./students.html')

# %%
z[1]
# Out:
#              0             1
# 0         Shop       Address
# 1  Ali mobiles         Sadar
# 2        Chase  Bahadur abad

# %%
a=pd.read_csv('test2.txt',na_values={'emp_age':'*','dept.':['-',''],'joining':''})

# %%
#a=pd.read_csv('test2.txt')

# %%
a.emp_age.unique
# Out:
# <bound method Series.unique of 0    42.0
# 1    25.0
# 2    16.0
# 3     NaN
# Name: emp_age, dtype: float64>

# %%
b=pd.read_csv('test2.csv' , header =None , names=['name','age','fname','address','ph#'],index_col='ph#')

# %%
pd.isnull(a)
# Out:
#    emp_id  emp_name  emp_age  dept.  joining
# 0   False     False    False  False    False
# 1   False     False    False   True    False
# 2   False     False    False   True     True
# 3   False     False     True   True     True

# %%
b
# Out:
#           name  age   fname address
# ph#
# 123456    asad   20    khan    abcd
# 245367  fayyaz   20  farooq    abcd

# %%
pd.isnull(b)
# Out:
#          name    age  fname  address
# ph#
# 123456  False  False  False    False
# 245367  False  False  False    False

# %%
def func_date_parser(month, day):
    #x = row.split(' ')

    if month == 'NaN' or day == 'NaN':
        return None
    return datetime.datetime(2018, int(month), int(day))

# %%
date_prac = pd.read_csv('./test_date_splitted.csv', parse_dates=[['joining_month', 'joining_day']], date_parser=func_date_parser)

# %%
date_prac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
# joining_month_joining_day    4 non-null datetime64[ns]
# emp_id                       4 non-null int64
# emp_name                     4 non-null object
# emp_age                      4 non-null object
# dept.                        3 non-null object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 240.0+ bytes

# %%
result = pd.read_csv('train.csv')

# %%
result.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
result.shape
# Out:
# (891, 12)

# %%
pd.options.display.max_rows = 10

# %%
result
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
chunker = pd.read_csv('train.csv', chunksize=200)

# %%
chunker

# %%
for rec in chunker:
    print(rec)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 195          196         1       1
# 196          197         0       3
# 197          198         0       3
# 198          199         1       3
# 199          200         0       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
obj = {"name": "Wes",
"places_lived": ["United States", "Spain", "Germany"],
"pet": 'null',
"siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},
{"name": "Katie", "age": 38,
"pets": ["Sixes", "Stache", "Cisco"]}]
}

# %%
obj
# Out:
# '\n{"name": "Wes",\n"places_lived": ["United States", "Spain", "Germany"],\n"pet": null,\n"siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},\n{"name": "Katie", "age": 38,\n"pets": ["Sixes", "Stache", "Cisco"]}]\n}\n'

# %%
siblings = pd.DataFrame(obj['siblings'], columns=['name', 'age'])

# %%
siblings
# Out:
#     name  age
# 0  Scott   30
# 1  Katie   38

# %%
x.to_pickle('data2.bin')

# %%
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'

# %%
resp = requests.get(url)

# %%
resp
# Out:
# <Response [200]>

# %%
data=resp.json()

# %%
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29381',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29381/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29381/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29381/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/29381',
#   'id': 516783350,
#   'node_id': 'MDU6SXNzdWU1MTY3ODMzNTA=',
#   'number': 29381,
#   'title': 'MemoryError when using `.drop_duplicates()`',
#   'user': {'login': 'Mikerah',
#    'id': 4249799,
#    'node_id': 'MDQ6VXNlcjQyNDk3OTk=',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/4249799?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Mikerah',
#    'html_url': 'https://github.com/Mikerah',
#    'followers_url': 'https://api.github.com/users/Mikerah/followers',
# ...

# %%
query = """
CREATE TABLE test (a VARCHAR(20), b VARCHAR(20), c REAL, d INTEGER);"""

# %%
con = sqlite3.connect('mydata.sqlite')

# %%
con.execute(query)

# %%
con.commit()

# %%
data = [('Atlanta', 'Georgia', 1.25, 6),
.....: ('Tallahassee', 'Florida', 2.6, 3),
.....: ('Sacramento', 'California', 1.7, 5)]

# %%
stmt = "INSERT INTO test VALUES(?, ?, ?, ?)"

# %%
con.executemany(stmt, data)

# %%
con.commit()

# %%
cursor = con.execute('select * from test')

# %%
rows = cursor.fetchall()

# %%
rows
# Out:
# [('Atlanta', 'Georgia', 1.25, 6),
#  ('Tallahassee', 'Florida', 2.6, 3),
#  ('Sacramento', 'California', 1.7, 5)]
